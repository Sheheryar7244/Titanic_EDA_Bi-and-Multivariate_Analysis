# %%
import pandas as pd
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **Bivariate Analysis & Multivariate Where Possible**

# %%
sns.scatterplot(x='age',y='fare',data=titanic,hue='survived')     #Multivariate->3 columns  ,scatterplot(Numerical-Numerical)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(x='survived',y='fare',data=titanic)    #Box Plot(Numerical-categorical)
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.barplot(x='survived',y='fare',data=titanic)  #Less_fare($0-$20)->died & High_fare(upto $50)->vipClass->survived
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.pairplot(titanic,hue='survived')    #pairplot(Numerical-Numerical)

# %%
sns.histplot(titanic[titanic['survived']==0]['age'],kde=True)    #shows children age(0 - 10)survival rate is high compared to deaths
sns.histplot(titanic[titanic['survived']==1]['age'],kde=True)     #adults(age>15)survival rate is low
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
titanic.pivot_table(values='age',index='pclass',columns='sex') #tells Ages of males and females in each class
# Out:
# sex        female       male
# pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %%
sns.heatmap(titanic.pivot_table(values='age',index='pclass',columns='sex'))
# Out:
# <Axes: xlabel='sex', ylabel='pclass'>
